# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/
# %cd agri-llm/
# %ls
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/agri-llm
# evaluate/  git_drive_setup.ipynb  models/  PAT.txt

# %%
with open('PAT.txt', 'r') as file:
    pat = file.read().strip()

# !git remote set-url origin https://dgm-acad:{pat}@github.com/dgm-acad/agri-llm.git

# %%
# !git config --global user.email "dinker.m@atriauniversity.edu.in"
# !git config --global user.name "dgm-acad"
# !git config --global credential.helper store

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 937 bytes | 16.00 KiB/s, done.
# From https://github.com/dgm-acad/agri-llm
#  * branch            main       -> FETCH_HEAD
#    b550a8c..05179bb  main       -> origin/main
# Updating b550a8c..05179bb
# Fast-forward
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "bunty"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6d12f33e182d.(none)')

# %%
# !git push origin main
# Out:
# Everything up-to-date
